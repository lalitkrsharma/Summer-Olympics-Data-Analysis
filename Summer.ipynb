# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# 5      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 7      1896  Athens   Aquatics             Swimming
# 8      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 10     1896  Athens   Aquatics             Swimming
# 11     1896  Athens  Athletics            Athletics
# 12     1896  Athens  Athletics            Athletics
# 13     1896  Athens  Athletics            Athletics
# 14     1896  Athens  Athletics            Athletics
# 15     1896  Athens  Athletics            Athletics
# 16     1896  Athens  Athletics            Athletics
# ...

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
len(df["City"].unique())
# Out:
# 22

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
gold= df[df['Medal']=='Gold']
gold.groupby('Sport').count()['Medal'].sort_values(ascending=False).head().plot.bar(figsize=(15, 5),color="Cyan")

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
df.groupby('Sport').count()['Medal'].sort_values(ascending=False).head().plot.bar(figsize=(15, 5),  color = 'Gold')

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
df.groupby('Athlete').count()['Medal'].sort_values(ascending=False).head().plot.bar(figsize=(15, 5), color = 'DarkBlue')

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
gold= df[df['Medal']=='Gold']
gold.groupby('Athlete').count()['Medal'].sort_values(ascending=False).head(5).plot.bar(figsize=(15, 5), color = 'Orange')

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
gold[gold['Country']=='IND']['Year'].min()
# Out:
# 1928

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
df.groupby("Event").count()['Athlete'].sort_values(ascending=False).head(5).plot.bar(figsize=(15, 5), color = 'Red')

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
data = []
for sport in df['Sport'].unique():
    data.append([sport , len(df[(df['Sport'] == sport) & (df['Medal'] == "Gold") & (df['Gender'] == "Women")])])

plot_data = pd.DataFrame(data,columns = ['Sport','No of female athlete']).sort_values(by='No of female athlete', ascending=False).head()

print("Top-5 Sport that having most female Gold Medalists \n")
print(plot_data)
plot_data.plot(x = 'Sport', y = 'No of female athlete', kind = 'bar', figsize = (15,5), color = "DarkCyan")
# Out:
# Top-5 Sport that having most female Gold Medalists
#
#          Sport  No of female athlete
# 0     Aquatics                   589
# 1    Athletics                   389
# 4   Gymnastics                   268
# 17      Rowing                   217
# 35  Volleyball                   166
